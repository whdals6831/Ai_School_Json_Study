# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('./data/data_mine.csv')
df
# Out:
#                 NAME GENDER  AGE BLOODTYPE  HEIGHT  WEIGHT
# 0      Jared Diamond      M   23         O   165.3    68.2
# 1     Sarah O'Donnel      F   22        AB   170.1    53.0
# 2       Brian Martin      M   24         B   175.0    80.1
# 3       David Hassel      M   23        AB   182.1    85.7
# 4    Clara Rodriquez      F   20         A   168.0    49.5
# 5   Jennifer Lorentz      F   21         O   162.0    52.0
# 6        Susan Clark      F   22         O   155.2    45.3
# 7    Margareth Jones      F   23         A   176.9    55.0
# 8       John Bertsch      M   23         B   178.5    64.2
# 9     Jake Timmerman      M   22         B   176.1    61.3
# 10     Joshua Connor      M   24         O   167.1    62.0
# 11      John Matsuda      M   22        AB   180.0    75.8
# 12      Eddy Johnson      M   21         A   162.2    55.3
# 13  Rebecah Anderson      F   23         O   176.1    53.1
# 14      Linda Carter      F   22         B   158.2    45.2
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17 entries, 0 to 16
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   NAME       17 non-null     object
#  1   GENDER     17 non-null     object
#  2   AGE        17 non-null     int64
#  3   BLOODTYPE  17 non-null     object
#  4   HEIGHT     17 non-null     float64
#  5   WEIGHT     17 non-null     float64
# dtypes: float64(2), int64(1), object(3)
# memory usage: 944.0+ bytes

# %%
df.describe()
# Out:
#              AGE      HEIGHT     WEIGHT
# count  17.000000   17.000000  17.000000
# mean   22.352941  170.035294  61.064706
# std     1.169464    7.849756  11.851685
# min    20.000000  155.200000  45.200000
# 25%    22.000000  165.300000  53.000000
# 50%    22.000000  169.200000  61.300000
# 75%    23.000000  176.100000  68.200000
# max    24.000000  182.100000  85.700000

# %%
df['WEIGHT'].mean()
# Out:
# 61.06470588235294

# %%
df2 = df.drop(columns='WEIGHT')
df2
# Out:
#                 NAME GENDER  AGE BLOODTYPE  HEIGHT
# 0      Jared Diamond      M   23         O   165.3
# 1     Sarah O'Donnel      F   22        AB   170.1
# 2       Brian Martin      M   24         B   175.0
# 3       David Hassel      M   23        AB   182.1
# 4    Clara Rodriquez      F   20         A   168.0
# 5   Jennifer Lorentz      F   21         O   162.0
# 6        Susan Clark      F   22         O   155.2
# 7    Margareth Jones      F   23         A   176.9
# 8       John Bertsch      M   23         B   178.5
# 9     Jake Timmerman      M   22         B   176.1
# 10     Joshua Connor      M   24         O   167.1
# 11      John Matsuda      M   22        AB   180.0
# 12      Eddy Johnson      M   21         A   162.2
# 13  Rebecah Anderson      F   23         O   176.1
# 14      Linda Carter      F   22         B   158.2
# 15    Richard Swayze      M   24         B   168.6
# 16      Andrew Daley      M   21         A   169.2

# %%
df3 = df.groupby(['GENDER','BLOODTYPE']).mean()
df3
# Out:
#                     AGE      HEIGHT     WEIGHT
# GENDER BLOODTYPE
# F      A          21.50  172.450000  52.250000
#        AB         22.00  170.100000  53.000000
#        B          22.00  158.200000  45.200000
#        O          22.00  164.433333  50.133333
# M      A          21.00  165.700000  58.750000
#        AB         22.50  181.050000  80.750000
#        B          23.25  174.550000  68.950000
#        O          23.50  166.200000  65.100000

# %%
df[df['NAME'] == 'Jared Diamond']
# Out:
#             NAME GENDER  AGE BLOODTYPE  HEIGHT  WEIGHT
# 0  Jared Diamond      M   23         O   165.3    68.2

# %%
df.sort_values(by=['AGE','HEIGHT'])
# Out:
#                 NAME GENDER  AGE BLOODTYPE  HEIGHT  WEIGHT
# 4    Clara Rodriquez      F   20         A   168.0    49.5
# 5   Jennifer Lorentz      F   21         O   162.0    52.0
# 12      Eddy Johnson      M   21         A   162.2    55.3
# 16      Andrew Daley      M   21         A   169.2    62.2
# 6        Susan Clark      F   22         O   155.2    45.3
# 14      Linda Carter      F   22         B   158.2    45.2
# 1     Sarah O'Donnel      F   22        AB   170.1    53.0
# 9     Jake Timmerman      M   22         B   176.1    61.3
# 11      John Matsuda      M   22        AB   180.0    75.8
# 0      Jared Diamond      M   23         O   165.3    68.2
# 13  Rebecah Anderson      F   23         O   176.1    53.1
# 7    Margareth Jones      F   23         A   176.9    55.0
# 8       John Bertsch      M   23         B   178.5    64.2
# 3       David Hassel      M   23        AB   182.1    85.7
# 10     Joshua Connor      M   24         O   167.1    62.0
# ...

# %%
plt.scatter(df['HEIGHT'], df['WEIGHT'])
plt.show()

# %%
df.loc[df['NAME']=='Andrew Daley',['NAME','BLOODTYPE']]
# Out:
#             NAME BLOODTYPE
# 16  Andrew Daley         A

# %%
k = df['BLOODTYPE'].value_counts()

blood_index = list(k.index)
blood_count = list(k.values)

kdf = pd.DataFrame({'blood_count': blood_count}, index=blood_index)

kdf.plot.bar(color='red', alpha=0.5)

plt.show()
